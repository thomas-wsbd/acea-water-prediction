# %%
import utils
from importlib import reload
reload(utils)
if os.path.exists('./data/geolocations.geojson'):
    gdf = gpd.read_file('./data/geolocations.geojson')
else:
    gdf = utils.returngeo()

# %%
# for the map
gdf['color'] = pd.factorize(gdf['feat'])[0]
gdf['lat'] = gdf['geometry'].y
gdf['lon'] = gdf['geometry'].x

import folium
icons = {'Rainfall': 'cloud', 'Temperature': 'sun-o', 'target': 'flag', 'Both': 'car'} # rainfall cloud, temperature sun, both (temperature & rainfall) flag
colors = ['navy', 'lightblue', 'blue', 'darkblue', 'darkgreen', 'orange', 'pink', 'purple', 'darkpurple', 'black', 'grey'] # blues aquifers, green lake, orange river, pinks water springs

m = folium.Map(location=[43.15, 12.07], zoom_start=8, tiles='cartodbpositron')
for i, row in gdf.iterrows():
    folium.Marker([row['lat'], row['lon']], tooltip='<b>name:</b> {}<br><b>parameters:</b> {}<br><b>adress:</b> {}<br><b>waterbody:</b> {}'.format(row['place'], row['param'], row['adress'], row['feat']), icon=folium.Icon(color=colors[row['color']], icon=icons.get(row['param']), prefix='fa')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
gdf
# Out:
#                  query               place  place_edit     param  \
# 215                  0           Bilancino         0.0    target
# 698                  0            Costanza         0.0    target
# 1040                 0           La Tura 2         0.0    target
# 1427                 0      Nave di Rosano         0.0    target
# 1428                 0      Nave di Rosano         0.0    target
# ...                ...                 ...         ...       ...
# 9     Sovicille, Italy           Sovicille         NaN  Rainfall
# 0                    0          Petrignano         0.0    target
# 1                    0           Doganella         0.0    target
# 2                    0  Madonna di Canetto         0.0    target
# 3                    0                Lupa         0.0    target
#
#                     feat                   geometry  \
# 215            Bilancino  POINT (11.28982 43.97497)
# 698                Auser  POINT (10.32362 43.80520)
# ...
